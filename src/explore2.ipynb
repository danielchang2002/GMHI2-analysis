# %%
import pandas as pd
df = pd.read_csv("../data/raw.csv", index_col=[1, 4])
df
# Out:
# /Users/daniel/opt/anaconda3/envs/data/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (11,12,13,15) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                             Unnamed: 0    Author (year) BoiProject ID  \
# Study_ID  Sample Accession
# GMHI-23   SAMEA3879547               0  Vogtmann (2016)    PRJEB12449
#           SAMEA3879551               1  Vogtmann (2016)    PRJEB12449
#           SAMEA3879543               2  Vogtmann (2016)    PRJEB12449
#           SAMEA3879565               3  Vogtmann (2016)    PRJEB12449
#           SAMEA3879546               4  Vogtmann (2016)    PRJEB12449
# ...                                ...              ...           ...
# GMHI-17   SAMEA2737871           12527     Zhang (2015)     PRJEB6997
#           SAMEA2737819           12528     Zhang (2015)     PRJEB6997
# ...

# %%
import numpy as np

np.unique(df['Disease status'], return_counts=True)
# Out:
# (array(['ACVD', 'Adenoma', 'Adenoma (MP)', 'Advanced Dementia',
#         'Behcet’s disease', 'Breast Cancer', 'CD', 'CRC',
#         'CRC (Stage III/IV)', 'Cancer', 'Control', "Crohn''s disease",
#         'Crohns disease', 'End-stage renal disease (ESRD)',
#         'Graves’ disease', 'Healthy', 'Healthy control',
#         'Hypertension (HTN)', 'IGT', 'Large adenoma', 'Liver Cirrhosis',
#         'NAFLD (Fibrosis stage 0)', 'NAFLD (Fibrosis stage 1)',
#         'NAFLD (Fibrosis stage 2)', 'NAFLD (Fibrosis stage 3)',
#         'NAFLD (Fibrosis stage 4)', 'Non–small cell lung cancer (NSCLC)',
#         'Normal', 'Obese', 'Obesity', 'Obesity with hepatic steatosis',
#         'Obesity/Overweight', 'Overweight', 'Pancreatic cancer',
#         'Renal cell carcinoma (RCC)', 'Rheumatoid Arthritis',
#         'Rheumatoid arthritis', 'Small adenoma', 'Stage_0', 'Stage_III_IV',
#         'Stage_I_II', 'T2D', 'UC', 'Ulcerative colitis', 'Underweight',
# ...

# %%
df.iloc[:, :20]
# Out:
#                             Unnamed: 0    Author (year) BoiProject ID  \
# Study_ID  Sample Accession
# GMHI-23   SAMEA3879547               0  Vogtmann (2016)    PRJEB12449
#           SAMEA3879551               1  Vogtmann (2016)    PRJEB12449
#           SAMEA3879543               2  Vogtmann (2016)    PRJEB12449
#           SAMEA3879565               3  Vogtmann (2016)    PRJEB12449
#           SAMEA3879546               4  Vogtmann (2016)    PRJEB12449
# ...                                ...              ...           ...
# GMHI-17   SAMEA2737871           12527     Zhang (2015)     PRJEB6997
#           SAMEA2737819           12528     Zhang (2015)     PRJEB6997
#           SAMEA2737851           12529     Zhang (2015)     PRJEB6997
# GMHI-V-38 SAMD00114974           12530    Thomas (2019)     PRJDB4176
# GMHI-3    SAMEA2466888           12531    Zeller (2014)     PRJEB6070
#
#                                  RunID  Sequencing Platform  \
# Study_ID  Sample Accession
# ...

# %%
np.unique(df["Sequencing Platform"], return_counts=True)
# Out:
# (array(['454 GS FLX Titanium', 'BGISEQ-500', 'HiSeq X Ten',
#         'Illumina Genome Analyzer II', 'Illumina Genome Analyzer IIx',
#         'Illumina HiSeq 1500', 'Illumina HiSeq 2000',
#         'Illumina HiSeq 2500', 'Illumina HiSeq 4000', 'Illumina MiSeq',
#         'Illumina NovaSeq 6000', 'Ion Torrent PGM', 'Ion Torrent Proton',
#         'NextSeq 500', 'NextSeq 550'], dtype=object),
#  array([  34,  385,  803,  696,  253,   27, 4601, 1888,  997,   75, 1328,
#           54,  218, 1111,   62]))

# %%
ndf.loc[studies[0]].iloc[:, :20]
# Out:
#                   Unnamed: 0    Author (year) BoiProject ID       RunID  \
# Sample Accession
# SAMEA3879547               0  Vogtmann (2016)    PRJEB12449  ERR1293689
# SAMEA3879551               1  Vogtmann (2016)    PRJEB12449  ERR1293705
# SAMEA3879543               2  Vogtmann (2016)    PRJEB12449  ERR1293673
# SAMEA3879565               3  Vogtmann (2016)    PRJEB12449  ERR1293761
# SAMEA3879546               4  Vogtmann (2016)    PRJEB12449  ERR1293685
# ...                      ...              ...           ...         ...
# SAMEA3879554           11146  Vogtmann (2016)    PRJEB12449  ERR1293717
# SAMEA3879507           11147  Vogtmann (2016)    PRJEB12449  ERR1293528
# SAMEA3879598           11148  Vogtmann (2016)    PRJEB12449  ERR1293893
# SAMEA3879595           11149  Vogtmann (2016)    PRJEB12449  ERR1293881
# SAMEA3879579           12346  Vogtmann (2016)    PRJEB12449  ERR1293817
#
#                   Sequencing Platform Library layout (SE/PE)  \
# Sample Accession
# ...

# %%
np.unique(df['Geographical Region or Population'], return_counts=True)
# Out:
# (array(['Austria', 'Burkina Faso', 'Cameroon', 'Canada', 'China',
#         'Denmark', 'Ethiopia', 'Finland', 'France', 'German', 'Germany',
#         'Ghana', 'India', 'Ireland', 'Israel', 'Italy', 'Italy: Milan',
#         'Italy: Vercelli', 'Japan', 'Kazakhstan', 'Madagascar', 'Mongolia',
#         'Netherlands', 'New Zealand', 'North America', 'Peru',
#         'South Korea', 'Spain', 'Sweden', 'Tanzania', 'USA',
#         'United Kingdom'], dtype=object),
#  array([ 156,   90,   57,   28, 3491,  647,   50,   42,  283,  111,  125,
#           44,  110,  118,  900,  275,   60,   80,  736,  172,  112,   63,
#          726,  226,  101,   29,   61,  163,  145,  108, 1978, 1245]))
