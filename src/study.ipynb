# %%
import pandas as pd
import numpy as np
from utils import get_species, get_labels, get_labels_all
from utils import get_taxonomy

# %%
X, y, y_all = get_taxonomy(), get_labels(), get_labels_all()

# %%
raw = pd.read_csv("../data/raw.csv", index_col=[1, 4])
# Out:
# /Users/daniel/opt/anaconda3/envs/data/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (11,12,13,15) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
np.unique(raw["Author (year)"])
# Out:
# array(['Ananthakrishnan (2017)', 'Ang (2021)', 'Araos (2019)',
#        'Asnicar (2021)', 'Backhed (2015)', 'Costea (2017)',
#        'Davies (2020)', 'De Filippis (2019)', 'Dhakan (2019)',
#        'D’Souza (2021)', 'Feng (2015)', 'Franzosa (2018)', 'Gu (2017)',
#        'Gupta (2020)',
#        'HMP1 (Phase-I): Structure, function and diversity of the healthy human microbiome (HMP1-2012)',
#        'HMP1 (Phase-II): Strains, functions and dynamics in the expanded Human Microbiome Project',
#        'Hannigan (2018)', 'Hansen (2018)', 'He (2017)', 'Hoyles (2018)',
#        'Jacobson (2021)', 'Jie (2017)', 'Karlsson (2013)',
#        'Keohane (2020)', 'Kim (2021)', 'Le Chatelier (2013)', 'Li (2017)',
#        'Liu (2016)', 'Lloyd-Price (2019)', 'Lokmer (2019)',
#        'Loomba (2017)', 'Matsukawa (2021)', 'Mehta (2018)',
#        'Meslier (2020)', 'Nielsen (2014)', 'Nishijima (2016)',
#        'Obregon-Tito (2015)', 'Pasolli (2019)', 'Qi (2019)', 'Qin (2012)',
#        'Qin (2014)', 'Rampelli (2020)', 'Rettedal (2021)',
#        'Roager (2019)', 'Routy (2018)', 'Schirmer (2016)',
#        'Schirmer (2018)', 'Smits (2017)', 'Sun (2021)', 'Tett (2019)',
#        'Thomas (2019)', 'Vogtmann (2016)', 'Wang (2020)', 'Wang (2021)',
#        'Wen (2017)', 'Weng (2019)', 'Wilson (2021)', 'Winglee (2017)',
#        'Wirbel (2019)', 'Xie (2016)', 'Yachida (2019)', 'Yassour (2018)',
#        'Ye (2018)', 'Yu (2015)', 'Zeevi (2015)', 'Zeller (2014)',
#        'Zhang (2015)', 'Zhu (2018)', 'Zhu (2020)', 'Zhu (2021)'],
#       dtype=object)

# %% [markdown]
# # Ananthakrishnan (2017)
#
# Abstract
#
# The gut microbiome plays a central role in inflammatory bowel diseases (IBDs) pathogenesis and propagation. To determine whether the gut microbiome may predict responses to IBD therapy, we conducted a prospective study with Crohn's disease (CD) or ulcerative colitis (UC) patients initiating anti-integrin therapy (vedolizumab). Disease activity and stool metagenomes at baseline, and weeks 14, 30, and 54 after therapy initiation were assessed. Community α-diversity was significantly higher, and Roseburia inulinivorans and a Burkholderiales species were more abundant at baseline among CD patients achieving week 14 remission. Several significant associations were identified with microbial function; 13 pathways including branched chain amino acid synthesis were significantly enriched in baseline samples from CD patients achieving remission. A neural network algorithm, vedoNet, incorporating microbiome and clinical data, provided highest classifying power for clinical remission. We hypothesize that the trajectory of early microbiome changes may be a marker of response to IBD treatment.

# %%
raw[(raw["Author (year)"] == "Ananthakrishnan (2017)")]
# Out:
#                            Unnamed: 0           Author (year) BoiProject ID  \
# Study_ID Sample Accession
# P57      SAMN06831159            7640  Ananthakrishnan (2017)   PRJNA384246
#          SAMN06831158            7641  Ananthakrishnan (2017)   PRJNA384246
#          SAMN06831157            7642  Ananthakrishnan (2017)   PRJNA384246
#          SAMN06831127            7643  Ananthakrishnan (2017)   PRJNA384246
#          SAMN06831132            7644  Ananthakrishnan (2017)   PRJNA384246
# ...                               ...                     ...           ...
#          SAMN06831219           10361  Ananthakrishnan (2017)   PRJNA384246
#          SAMN06831215           10362  Ananthakrishnan (2017)   PRJNA384246
#          SAMN06831150           10363  Ananthakrishnan (2017)   PRJNA384246
#          SAMN06831171           10364  Ananthakrishnan (2017)   PRJNA384246
#          SAMN06831116           10365  Ananthakrishnan (2017)   PRJNA384246
#
#                                 RunID Sequencing Platform  \
# Study_ID Sample Accession
# P57      SAMN06831159      SRR8956684         NextSeq 500
#          SAMN06831158      SRR8956683         NextSeq 500
#          SAMN06831157      SRR8956682         NextSeq 500
#          SAMN06831127      SRR8956674         NextSeq 500
#          SAMN06831132      SRR8956669         NextSeq 500
# ...                               ...                 ...
#          SAMN06831219      SRR8956549         NextSeq 500
#          SAMN06831215      SRR8956543         NextSeq 500
#          SAMN06831150      SRR8956539         NextSeq 500
#          SAMN06831171      SRR8956530         NextSeq 500
#          SAMN06831116      SRR8956513         NextSeq 500
#
#                           Library layout (SE/PE)  \
# Study_ID Sample Accession
# P57      SAMN06831159                     SINGLE
#          SAMN06831158                     SINGLE
#          SAMN06831157                     SINGLE
#          SAMN06831127                     SINGLE
#          SAMN06831132                     SINGLE
# ...                                          ...
#          SAMN06831219                     SINGLE
#          SAMN06831215                     SINGLE
#          SAMN06831150                     SINGLE
#          SAMN06831171                     SINGLE
#          SAMN06831116                     SINGLE
#
#                           Sample origin? (e.g., stool, mucosa) Disease status  \
# Study_ID Sample Accession
# P57      SAMN06831159                                    Stool             CD
#          SAMN06831158                                    Stool             CD
#          SAMN06831157                                    Stool             CD
#          SAMN06831127                                    Stool             CD
#          SAMN06831132                                    Stool             CD
# ...                                                        ...            ...
#          SAMN06831219                                    Stool             UC
#          SAMN06831215                                    Stool             UC
#          SAMN06831150                                    Stool             UC
#          SAMN06831171                                    Stool             UC
#          SAMN06831116                                    Stool             UC
#
#                           Sample_ID Subject Id (If available)  ...  \
# Study_ID Sample Accession                                      ...
# P57      SAMN06831159        G98932                     P9586  ...
#          SAMN06831158        G89920                     P7068  ...
#          SAMN06831157        G89921                     P9157  ...
#          SAMN06831127        G98885                     P9510  ...
#          SAMN06831132        G98762                     P7266  ...
# ...                             ...                       ...  ...
#          SAMN06831219        G90065                     P9322  ...
#          SAMN06831215        G90061                     P9289  ...
#          SAMN06831150        G89961                     P8605  ...
#          SAMN06831171        G98790                     P9511  ...
#          SAMN06831116        G98773                     P9430  ...
#
#                           k__Viruses|p__Viruses_unclassified|c__Viruses_unclassified|o__Viruses_unclassified|f__Virgaviridae|g__Hordeivirus|s__Barley_stripe_mosaic_virus  \
# Study_ID Sample Accession
# P57      SAMN06831159                                                      0
#          SAMN06831158                                                      0
#          SAMN06831157                                                      0
#          SAMN06831127                                                      0
#          SAMN06831132                                                      0
# ...                                                                      ...
#          SAMN06831219                                                      0
#          SAMN06831215                                                      0
#          SAMN06831150                                                      0
#          SAMN06831171                                                      0
#          SAMN06831116                                                      0
#
#                           k__Viruses|p__Viruses_unclassified|c__Viruses_unclassified|o__Viruses_unclassified|f__Virgaviridae|g__Tobamovirus  \
# Study_ID Sample Accession
# P57      SAMN06831159                                                    0.0
#          SAMN06831158                                                    0.0
#          SAMN06831157                                                    0.0
#          SAMN06831127                                                    0.0
#          SAMN06831132                                                    0.0
# ...                                                                      ...
#          SAMN06831219                                                    0.0
#          SAMN06831215                                                    0.0
#          SAMN06831150                                                    0.0
#          SAMN06831171                                                    0.0
#          SAMN06831116                                                    0.0
#
#                           k__Viruses|p__Viruses_unclassified|c__Viruses_unclassified|o__Viruses_unclassified|f__Virgaviridae|g__Tobamovirus|s__Cactus_mild_mottle_virus  \
# Study_ID Sample Accession
# P57      SAMN06831159                                                    0.0
#          SAMN06831158                                                    0.0
#          SAMN06831157                                                    0.0
#          SAMN06831127                                                    0.0
#          SAMN06831132                                                    0.0
# ...                                                                      ...
#          SAMN06831219                                                    0.0
#          SAMN06831215                                                    0.0
#          SAMN06831150                                                    0.0
#          SAMN06831171                                                    0.0
#          SAMN06831116                                                    0.0
#
#                           k__Viruses|p__Viruses_unclassified|c__Viruses_unclassified|o__Viruses_unclassified|f__Virgaviridae|g__Tobamovirus|s__Cucumber_green_mottle_mosaic_virus  \
# Study_ID Sample Accession
# P57      SAMN06831159                                                    0.0
#          SAMN06831158                                                    0.0
#          SAMN06831157                                                    0.0
#          SAMN06831127                                                    0.0
#          SAMN06831132                                                    0.0
# ...                                                                      ...
#          SAMN06831219                                                    0.0
#          SAMN06831215                                                    0.0
#          SAMN06831150                                                    0.0
#          SAMN06831171                                                    0.0
#          SAMN06831116                                                    0.0
#
#                           k__Viruses|p__Viruses_unclassified|c__Viruses_unclassified|o__Viruses_unclassified|f__Virgaviridae|g__Tobamovirus|s__Paprika_mild_mottle_virus  \
# Study_ID Sample Accession
# P57      SAMN06831159                                                    0.0
#          SAMN06831158                                                    0.0
#          SAMN06831157                                                    0.0
#          SAMN06831127                                                    0.0
#          SAMN06831132                                                    0.0
# ...                                                                      ...
#          SAMN06831219                                                    0.0
#          SAMN06831215                                                    0.0
#          SAMN06831150                                                    0.0
#          SAMN06831171                                                    0.0
#          SAMN06831116                                                    0.0
#
#                           k__Viruses|p__Viruses_unclassified|c__Viruses_unclassified|o__Viruses_unclassified|f__Virgaviridae|g__Tobamovirus|s__Pepper_mild_mottle_virus  \
# Study_ID Sample Accession
# P57      SAMN06831159                                                    0.0
#          SAMN06831158                                                    0.0
#          SAMN06831157                                                    0.0
#          SAMN06831127                                                    0.0
#          SAMN06831132                                                    0.0
# ...                                                                      ...
#          SAMN06831219                                                    0.0
#          SAMN06831215                                                    0.0
#          SAMN06831150                                                    0.0
#          SAMN06831171                                                    0.0
#          SAMN06831116                                                    0.0
#
#                            k__Viruses|p__Viruses_unclassified|c__Viruses_unclassified|o__Viruses_unclassified|f__Virgaviridae|g__Tobamovirus|s__Tobacco_mild_green_mosaic_virus  \
# Study_ID Sample Accession
# P57      SAMN06831159                                                    0.0
#          SAMN06831158                                                    0.0
#          SAMN06831157                                                    0.0
#          SAMN06831127                                                    0.0
#          SAMN06831132                                                    0.0
# ...                                                                      ...
#          SAMN06831219                                                    0.0
#          SAMN06831215                                                    0.0
#          SAMN06831150                                                    0.0
#          SAMN06831171                                                    0.0
#          SAMN06831116                                                    0.0
#
#                            k__Viruses|p__Viruses_unclassified|c__Viruses_unclassified|o__Viruses_unclassified|f__Viruses_unclassified|g__Viruses_unclassified|s__Deep_sea_thermophilic_phage_D6E  \
# Study_ID Sample Accession
# P57      SAMN06831159                                                    0.0
#          SAMN06831158                                                    0.0
#          SAMN06831157                                                    0.0
#          SAMN06831127                                                    0.0
#          SAMN06831132                                                    0.0
# ...                                                                      ...
#          SAMN06831219                                                    0.0
#          SAMN06831215                                                    0.0
#          SAMN06831150                                                    0.0
#          SAMN06831171                                                    0.0
#          SAMN06831116                                                    0.0
#
#                            k__Viruses|p__Viruses_unclassified|c__Viruses_unclassified|o__Viruses_unclassified|f__Viruses_unclassified|g__Viruses_unclassified|s__Loktanella_phage_pCB2051_A  \
# Study_ID Sample Accession
# P57      SAMN06831159                                                    0.0
#          SAMN06831158                                                    0.0
#          SAMN06831157                                                    0.0
#          SAMN06831127                                                    0.0
#          SAMN06831132                                                    0.0
# ...                                                                      ...
#          SAMN06831219                                                    0.0
#          SAMN06831215                                                    0.0
#          SAMN06831150                                                    0.0
#          SAMN06831171                                                    0.0
#          SAMN06831116                                                    0.0
#
#                            k__Viruses|p__Viruses_unclassified|c__Viruses_unclassified|o__Viruses_unclassified|f__Viruses_unclassified|g__Viruses_unclassified|s__Tetraselmis_viridis_virus_S1
# Study_ID Sample Accession
# P57      SAMN06831159                                                    0.0
#          SAMN06831158                                                    0.0
#          SAMN06831157                                                    0.0
#          SAMN06831127                                                    0.0
#          SAMN06831132                                                    0.0
# ...                                                                      ...
#          SAMN06831219                                                    0.0
#          SAMN06831215                                                    0.0
#          SAMN06831150                                                    0.0
#          SAMN06831171                                                    0.0
#          SAMN06831116                                                    0.0
#
# [81 rows x 3217 columns]
